# %% [markdown]
# # Neural Network Methods 1

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Notebook objectives:</b>
#
# * Apply NNs methods to train and test generalization classification on:
#
#     - Baseline data set
#     - Class Imbalance treatment data set
#     - Evolutionary Algorithm regularizaion
#
# * Compile the results of the performance metrics

# %%
# if Notebook set up throws and error uncomment and install keras and reset kernel
# !pip install keras

# %%
# if Notebook set up throws and error uncomment and install tensorflow and reset kernel
# !pip install tensorflow

# %%
# Upgrade  tensorflow and tensflow gpu to latest version
# !pip install --upgrade tensorflow
# !pip install --upgrade tensorflow-gpu

# %%
# Try downgrading pandas version if pickle throws an error while loading and reset kernel
# !pip install pandas==1.4.1

# %% [markdown]
# # 1. Notebook set up

# %%
###### Import packages

### Data handling
import numpy as np
import pandas as pd
import datetime as dt
#from IPython.display import HTML, Image #display formatted texts
import warnings
warnings.filterwarnings('ignore')

### Plotting packages
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn') # pretty graphs
import matplotlib.ticker as mticker
from matplotlib.ticker import FormatStrFormatter, StrMethodFormatter, FuncFormatter
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go


### Files to pickle
import pickle
import bz2
import _pickle as cPickle

### sampling
from sklearn.model_selection import train_test_split

### sk-learn pipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer

### Model selection

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.gaussian_process.kernels import RBF
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier

# if xgboost throws and error uncomment and install xgboost package
# !pip install xgboost
# from xgboost import XGBClassifier
# from xgboost import plot_importance, to_graphviz

# Pipeline
from sklearn.pipeline import Pipeline
from sklearn.compose import make_column_transformer

# Cross-validation
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV

# Dimensionality reduction
from sklearn.decomposition import PCA


from sklearn.metrics import confusion_matrix, roc_curve, auc, roc_auc_score, accuracy_score, precision_score, recall_score, average_precision_score, f1_score
from sklearn.inspection import partial_dependence


# NN methods
import tensorflow as tf
from tensorflow import keras 
from keras.models import Sequential 
from keras.layers import Dense, Dropout,Conv1D
from keras.utils  import np_utils 

# time progress bar
from tqdm.notebook import tqdm_notebook
from tqdm import tqdm
import time

# Google path set up
pickles = "/content/drive/MyDrive/pickles/"
pickles_w1 = "/content/drive/MyDrive/pickles/w1/"
pickles_w2 = "/content/drive/MyDrive/pickles/w2/"
pickles_w3 = "/content/drive/MyDrive/pickles/w3/"
pickles_w4 = "/content/drive/MyDrive/pickles/w4/"
pickles_w5 = "/content/drive/MyDrive/pickles/w5/"
pickles_imbalance = "/content/drive/MyDrive/pickles/class_imbalance_learn/"

# Path set up
path = "/project/data/"
path_w1 = "/project/data/w1/"
path_w2 = "/project/data/w2/"
path_w3 = "/project/data/w3/"
path_w4 = "/project/data/w4/"
path_w5 = "/project/data/w5/"
path_feature = "/project/data/feature_importance/"


# fixed values
seed = 2323
colors = {'c1':['blue', 'red'], 'c2': ['red', 'blue', 'grey', 'purple']}
bar_width = 0.3
bin_num = 25
size = {'small_tick': 9, 'tick': 10 , 'label': 14, 'sub_title': 16, 'main_title': 20}
fig_size = {'large': (30,25), 'small': (10, 5)}

# pandas display set up
pd.options.display.max_columns = None

# %% [markdown]
# # 2. Loading pre-processed X and y

# %%
# Loading X
pickled_data_X = bz2.BZ2File(path_w2 + 'X_train_dense_w2_1pct', 'rb')
X = cPickle.load(pickled_data_X)
pickled_data_X.close()
print(F"X_train shape: rows {X.shape[0]}, columns {X.shape[1]}")
# Out:
# X_train shape: rows 338282, columns 304

# %%
# Loading y
pickled_data_y = bz2.BZ2File(path_w2 + 'y_train_dense_w2_1pct', 'rb')
y = cPickle.load(pickled_data_y)
pickled_data_X.close()
print(F"X_train shape: rows {y.shape[0]}, columns 1")
# Out:
# X_train shape: rows 338282, columns 1

# %%
# Loading X resampled
pickled_data_X = bz2.BZ2File(path_w2 + 'X_resampled_w2_1pct', 'rb')
X_resampled = cPickle.load(pickled_data_X)
pickled_data_X.close()
print(F"X_train shape: rows {X_resampled.shape[0]}, columns {X_resampled.shape[1]}")
# Out:
# X_train shape: rows 101415, columns 304

# %%
# Loading X resampled
pickled_data_y = bz2.BZ2File(path_w2 + 'y_resampled_w2_1pct', 'rb')
y_resampled = cPickle.load(pickled_data_y)
pickled_data_X.close()
print(F"X_train shape: rows {y_resampled.shape[0]}, columns 1")
# Out:
# X_train shape: rows 101415, columns 1

# %%
# Loading X test
pickled_data_X = bz2.BZ2File(path_w2 + 'X_test_dense_w2_1pct', 'rb')
X_test_dense = cPickle.load(pickled_data_X)
pickled_data_X.close()
print(F"X_train shape: rows {X_test_dense.shape[0]}, columns {X_test_dense.shape[1]}")
# Out:
# X_train shape: rows 59697, columns 304

# %%
# Loading y test
pickled_data_y = bz2.BZ2File(path_w2 + 'y_test_dense_w2_1pct', 'rb')
y_test_dense = cPickle.load(pickled_data_y)
pickled_data_y.close()
print(F"y_train shape: rows {y_test_dense.shape[0]}, columns 1")
# y_train = np.array(y_train)
# Out:
# y_train shape: rows 59697, columns 1

# %% [markdown]
# # 3. Neural Network methods

# %%
def models_function(X):

  # Model 1 
  # Input layer: Number of features
  # Hiden layer: 2*Num of features
  # Turns off 40% of neurons
  # Capa oculta: 2*Num of features
  # Turns off 40% of neurons
  # Hiden layer: Num of features
  # Turns off 40% of neurons
  # Output layer: 1 neuron
  # Hyper Parameters: Loss function -> binary cross entropy, metrics: Recall y AUC, Optimizer: Adam 
  n_columns = X.shape[1]

  model = Sequential()
  model.add(Dense(units=n_columns, activation='relu'))
  model.add(Dropout(0.4))
  model.add(Dense(units=n_columns*2, activation='relu'))
  model.add(Dropout(0.4))
  model.add(Dense(units=n_columns*2, activation='relu'))
  model.add(Dropout(0.4))
  model.add(Dense(units=n_columns, activation='relu'))
  model.add(Dropout(0.4))
  model.add(Dense(units=1, activation = 'sigmoid'))
  model.compile(loss = 'binary_crossentropy', metrics=['Recall', 'AUC'], 
                optimizer = 'adam')



  # Model 2
  # Input layer: Number of features 
  # Turns off 40% of neurons 
  # Hiden layer: Num of features
  # Turns off 40% of neurons
  # Output layer: 1 neuron
  # Characteristics: Loss function -> binary cross entropy, metrics: Recall y AUC, Optimizer: Adam 
  n_columns = X.shape[1]

  model2 = Sequential()
  model2.add(Dense(units=n_columns, activation='relu'))
  model2.add(Dropout(0.4))
  model2.add(Dense(units=n_columns, activation='relu'))
  model2.add(Dropout(0.4))
  model2.add(Dense(units=1, activation = 'sigmoid'))
  model2.compile(loss = 'binary_crossentropy', metrics=['Recall', 'AUC'], 
                optimizer = 'adam')



  # Model 3
  # Input layer: Number of features 
  # Turns off 40% of neurons 
  # Hiden layer: Num of features divided by 2  
  # Turns off 40% of neurons 
  # Hiden layer: Num of features divided by 4 
  # Turns off 40% of neurons 
  # Hiden layer: Num of features divided by 2  
  # Turns off 40% of neurons 
  # Input layer: Number of features 
  # Turns off 40% of neurons 
  # Output layer: 1 neuron
  # Characteristics: Loss function -> binary cross entropy, metrics: Recall y AUC, Optimizer: Adam 

  n_columns = X.shape[1]

  model3 = Sequential()
  model3.add(Dense(units=n_columns, activation='relu'))
  model3.add(Dropout(0.4))
  model3.add(Dense(units=int(n_columns/2), activation='relu'))
  model3.add(Dropout(0.4))
  model3.add(Dense(units=int(n_columns/4), activation='relu'))
  model3.add(Dropout(0.4))
  model3.add(Dense(units=int(n_columns/2), activation='relu'))
  model3.add(Dropout(0.4))
  model3.add(Dense(units=n_columns, activation='relu'))
  model3.add(Dropout(0.4))
  model3.add(Dense(units=1, activation = 'sigmoid'))
  model3.compile(loss = 'binary_crossentropy', metrics=['Recall', 'AUC'], 
                optimizer = 'adam')

  # Modelo 4
  # Input layer: Number of features 
  # Turns off 40% of neurons 
  # Hiden layer: Num of features divided by 2  
  # Turns off 40% of neurons 
  # Hiden layer: Num of features divided by 4 
  # Turns off 40% of neurons 
  # Hiden layer: Num of features divided by 8
  # Turns off 40% of neurons 
  # Hiden layer: Num of features divided by 4 
  # Turns off 40% of neurons 
  # Hiden layer: Num of features divided by 2  
  # Turns off 40% of neurons 
  # Input layer: Number of features  
  # Turns off 40% of neurons 
  # Output layer: 1 neuron 
  # Characteristics: Loss function -> binary cross entropy, metrics: Recall y AUC, Optimizer: Adam 
  n_columns = X.shape[1]

  model4 = Sequential()
  model4.add(Dense(units=n_columns, activation='relu'))
  model4.add(Dropout(0.4))
  model4.add(Dense(units=int(n_columns/2), activation='relu'))
  model4.add(Dropout(0.4))
  model4.add(Dense(units=int(n_columns/4), activation='relu'))
  model4.add(Dropout(0.4))
  model4.add(Dense(units=int(n_columns/8), activation='relu'))
  model4.add(Dropout(0.4))
  model4.add(Dense(units=int(n_columns/4), activation='relu'))
  model4.add(Dropout(0.4))
  model4.add(Dense(units=int(n_columns/2), activation='relu'))
  model4.add(Dropout(0.4))
  model4.add(Dense(units=n_columns, activation='relu'))
  model4.add(Dropout(0.4))
  model4.add(Dense(units=1, activation = 'sigmoid'))
  model4.compile(loss = 'binary_crossentropy', metrics=['Recall', 'AUC'], 
                optimizer = 'adam')
  return model, model2, model3, model4

# %% [markdown]
# ## 3.1 Baseline predictions

# %%
X = X_data
y = y_data

# %%
models = models_function(X)

# %%
Results = pd.DataFrame()
recall = []
auc = []
name= []
i = 1
for model in models:
    model.fit(X, y, batch_size = 128, epochs = 20, verbose = 1)
    pred = model.predict(X_test_dense)
    score = model.evaluate(X_test_dense, y_test_dense, verbose=1)
    print('Loss Function:', score[0])
    print('Test recall:', score[1])
    print('Test auc:', score[2])
    print(model.summary())
    auc.append(score[2])
    recall.append(score[1])
    name.append('model_number_{}'.format(i))
    i = i+1

Results['Modelo'] = name
Results['AUC'] = auc 
Results['Recall'] = recall
# Out:
# Epoch 1/20
# 2488/2488 [==============================] - 61s 24ms/step - loss: 0.0113 - recall: 0.0000e+00 - auc: 0.5080
# Epoch 2/20
# 2488/2488 [==============================] - 60s 24ms/step - loss: 0.0091 - recall: 0.0000e+00 - auc: 0.5054
# Epoch 3/20
# 2488/2488 [==============================] - 59s 24ms/step - loss: 0.0101 - recall: 0.0000e+00 - auc: 0.5254
# Epoch 4/20
# 2488/2488 [==============================] - 60s 24ms/step - loss: 0.0121 - recall: 0.0000e+00 - auc: 0.5103
# Epoch 5/20
# 2488/2488 [==============================] - 59s 24ms/step - loss: 0.0157 - recall: 0.0000e+00 - auc: 0.5041
# Epoch 6/20
# 2488/2488 [==============================] - 59s 24ms/step - loss: 0.0124 - recall: 0.0000e+00 - auc: 0.4923
# Epoch 7/20
# 2488/2488 [==============================] - 59s 24ms/step - loss: 0.0104 - recall: 0.0000e+00 - auc: 0.5158
# Epoch 8/20
# 2488/2488 [==============================] - 59s 24ms/step - loss: 0.0103 - recall: 0.0000e+00 - auc: 0.5142
# Epoch 9/20
# 2488/2488 [==============================] - 59s 24ms/step - loss: 0.0104 - recall: 0.0000e+00 - auc: 0.4978
# Epoch 10/20
# 2488/2488 [==============================] - 59s 24ms/step - loss: 0.0127 - recall: 0.0000e+00 - auc: 0.5054
# Epoch 11/20
# 2488/2488 [==============================] - 60s 24ms/step - loss: 0.0126 - recall: 0.0000e+00 - auc: 0.5298
# Epoch 12/20
# 2488/2488 [==============================] - 60s 24ms/step - loss: 0.0135 - recall: 0.0000e+00 - auc: 0.5114
# Epoch 13/20
# 2488/2488 [==============================] - 59s 24ms/step - loss: 0.0109 - recall: 0.0000e+00 - auc: 0.5188
# Epoch 14/20
# 2488/2488 [==============================] - 59s 24ms/step - loss: 0.0110 - recall: 0.0000e+00 - auc: 0.4881
# Epoch 15/20
# 2488/2488 [==============================] - 59s 24ms/step - loss: 0.0093 - recall: 0.0000e+00 - auc: 0.5053
# Epoch 16/20
# 2488/2488 [==============================] - 59s 24ms/step - loss: 0.0086 - recall: 0.0000e+00 - auc: 0.4974
# Epoch 17/20
# 2488/2488 [==============================] - 60s 24ms/step - loss: 0.0088 - recall: 0.0000e+00 - auc: 0.5051
# Epoch 18/20
# 2488/2488 [==============================] - 59s 24ms/step - loss: 0.0071 - recall: 0.0000e+00 - auc: 0.4982
# Epoch 19/20
# 2488/2488 [==============================] - 59s 24ms/step - loss: 0.0085 - recall: 0.0000e+00 - auc: 0.5006
# Epoch 20/20
# 2488/2488 [==============================] - 60s 24ms/step - loss: 0.0082 - recall: 0.0000e+00 - auc: 0.4982
# 2488/2488 [==============================] - 11s 4ms/step - loss: 0.0087 - recall: 0.0000e+00 - auc: 0.5000
# Loss Function: 0.008671252988278866
# Test recall: 0.0
# Test auc: 0.5
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_44 (Dense)            (None, 304)               92720
#
#  dropout_36 (Dropout)        (None, 304)               0
#
#  dense_45 (Dense)            (None, 608)               185440
#
#  dropout_37 (Dropout)        (None, 608)               0
#
#  dense_46 (Dense)            (None, 608)               370272
#
#  dropout_38 (Dropout)        (None, 608)               0
#
#  dense_47 (Dense)            (None, 304)               185136
#
#  dropout_39 (Dropout)        (None, 304)               0
#
#  dense_48 (Dense)            (None, 1)                 305
#
# =================================================================
# Total params: 833,873
# Trainable params: 833,873
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 2488/2488 [==============================] - 21s 8ms/step - loss: 0.0074 - recall: 0.0000e+00 - auc: 0.5080
# Epoch 2/20
# 2488/2488 [==============================] - 20s 8ms/step - loss: 0.0064 - recall: 0.0000e+00 - auc: 0.5194
# Epoch 3/20
# 2488/2488 [==============================] - 19s 8ms/step - loss: 0.0063 - recall: 0.0000e+00 - auc: 0.5559
# Epoch 4/20
# 2488/2488 [==============================] - 19s 8ms/step - loss: 0.0062 - recall: 0.0000e+00 - auc: 0.5444
# Epoch 5/20
# 2488/2488 [==============================] - 19s 8ms/step - loss: 0.0066 - recall: 0.0000e+00 - auc: 0.5441
# Epoch 6/20
# 2488/2488 [==============================] - 20s 8ms/step - loss: 0.0071 - recall: 0.0000e+00 - auc: 0.5235
# Epoch 7/20
# 2488/2488 [==============================] - 20s 8ms/step - loss: 0.0064 - recall: 0.0000e+00 - auc: 0.5796
# Epoch 8/20
# 2488/2488 [==============================] - 20s 8ms/step - loss: 0.0062 - recall: 0.0000e+00 - auc: 0.5809
# Epoch 9/20
# 2488/2488 [==============================] - 19s 8ms/step - loss: 0.0058 - recall: 0.0280 - auc: 0.6477
# Epoch 10/20
# 2488/2488 [==============================] - 20s 8ms/step - loss: 0.0054 - recall: 0.0421 - auc: 0.6818
# Epoch 11/20
# 2488/2488 [==============================] - 20s 8ms/step - loss: 0.0066 - recall: 0.0701 - auc: 0.7140
# Epoch 12/20
# 2488/2488 [==============================] - 20s 8ms/step - loss: 0.0047 - recall: 0.0467 - auc: 0.7396
# Epoch 13/20
# 2488/2488 [==============================] - 22s 9ms/step - loss: 0.0043 - recall: 0.1028 - auc: 0.7198
# Epoch 14/20
# 2488/2488 [==============================] - 26s 11ms/step - loss: 0.0040 - recall: 0.1308 - auc: 0.7650
# Epoch 15/20
# 2488/2488 [==============================] - 19s 8ms/step - loss: 0.0040 - recall: 0.1636 - auc: 0.7510
# Epoch 16/20
# 2488/2488 [==============================] - 21s 8ms/step - loss: 0.0044 - recall: 0.1542 - auc: 0.7501
# Epoch 17/20
# 2488/2488 [==============================] - 20s 8ms/step - loss: 0.0041 - recall: 0.1168 - auc: 0.7732
# Epoch 18/20
# 2488/2488 [==============================] - 23s 9ms/step - loss: 0.0040 - recall: 0.1589 - auc: 0.7437
# Epoch 19/20
# 2488/2488 [==============================] - 26s 10ms/step - loss: 0.0035 - recall: 0.2196 - auc: 0.7991
# Epoch 20/20
# 2488/2488 [==============================] - 20s 8ms/step - loss: 0.0032 - recall: 0.2383 - auc: 0.8082
# 2488/2488 [==============================] - 5s 2ms/step - loss: 0.0093 - recall: 0.0000e+00 - auc: 0.4992
# Loss Function: 0.00925678201019764
# Test recall: 0.0
# Test auc: 0.499226838350296
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_49 (Dense)            (None, 304)               92720
#
#  dropout_40 (Dropout)        (None, 304)               0
#
#  dense_50 (Dense)            (None, 304)               92720
#
#  dropout_41 (Dropout)        (None, 304)               0
#
#  dense_51 (Dense)            (None, 1)                 305
#
# =================================================================
# Total params: 185,745
# Trainable params: 185,745
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 2488/2488 [==============================] - 30s 12ms/step - loss: 0.0109 - recall: 0.0000e+00 - auc: 0.4942
# Epoch 2/20
# 2488/2488 [==============================] - 26s 11ms/step - loss: 0.0090 - recall: 0.0000e+00 - auc: 0.5417
# Epoch 3/20
# 2488/2488 [==============================] - 33s 13ms/step - loss: 0.0087 - recall: 0.0000e+00 - auc: 0.5110
# Epoch 4/20
# 2488/2488 [==============================] - 29s 12ms/step - loss: 0.0093 - recall: 0.0000e+00 - auc: 0.5193
# Epoch 5/20
# 2488/2488 [==============================] - 29s 12ms/step - loss: 0.0093 - recall: 0.0000e+00 - auc: 0.5028
# Epoch 6/20
# 2488/2488 [==============================] - 26s 10ms/step - loss: 0.0085 - recall: 0.0000e+00 - auc: 0.5068
# Epoch 7/20
# 2488/2488 [==============================] - 27s 11ms/step - loss: 0.0092 - recall: 0.0000e+00 - auc: 0.4941
# Epoch 8/20
# 2488/2488 [==============================] - 27s 11ms/step - loss: 0.0094 - recall: 0.0000e+00 - auc: 0.5021
# Epoch 9/20
# 2488/2488 [==============================] - 29s 12ms/step - loss: 0.0106 - recall: 0.0000e+00 - auc: 0.5044
# Epoch 10/20
# 2488/2488 [==============================] - 32s 13ms/step - loss: 0.0101 - recall: 0.0000e+00 - auc: 0.5023
# Epoch 11/20
# 2488/2488 [==============================] - 27s 11ms/step - loss: 0.0085 - recall: 0.0000e+00 - auc: 0.5031
# Epoch 12/20
# 2488/2488 [==============================] - 25s 10ms/step - loss: 0.0093 - recall: 0.0000e+00 - auc: 0.4930
# Epoch 13/20
# 2488/2488 [==============================] - 26s 10ms/step - loss: 0.0069 - recall: 0.0000e+00 - auc: 0.4984
# Epoch 14/20
# 2488/2488 [==============================] - 26s 11ms/step - loss: 0.0095 - recall: 0.0000e+00 - auc: 0.5058
# Epoch 15/20
# 2488/2488 [==============================] - 29s 12ms/step - loss: 0.0114 - recall: 0.0000e+00 - auc: 0.4959
# Epoch 16/20
# 2488/2488 [==============================] - 33s 13ms/step - loss: 0.0078 - recall: 0.0000e+00 - auc: 0.4983
# Epoch 17/20
# 2488/2488 [==============================] - 32s 13ms/step - loss: 0.0070 - recall: 0.0000e+00 - auc: 0.4993
# Epoch 18/20
# 2488/2488 [==============================] - 31s 13ms/step - loss: 0.0082 - recall: 0.0000e+00 - auc: 0.5009
# Epoch 19/20
# 2488/2488 [==============================] - 29s 12ms/step - loss: 0.0108 - recall: 0.0000e+00 - auc: 0.4992
# Epoch 20/20
# 2488/2488 [==============================] - 26s 10ms/step - loss: 0.0086 - recall: 0.0000e+00 - auc: 0.4983
# 2488/2488 [==============================] - 6s 2ms/step - loss: 0.0056 - recall: 0.0000e+00 - auc: 0.5000
# Loss Function: 0.005643636453896761
# Test recall: 0.0
# Test auc: 0.5
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_52 (Dense)            (None, 304)               92720
#
#  dropout_42 (Dropout)        (None, 304)               0
#
#  dense_53 (Dense)            (None, 152)               46360
#
#  dropout_43 (Dropout)        (None, 152)               0
#
#  dense_54 (Dense)            (None, 76)                11628
#
#  dropout_44 (Dropout)        (None, 76)                0
#
#  dense_55 (Dense)            (None, 152)               11704
#
#  dropout_45 (Dropout)        (None, 152)               0
#
#  dense_56 (Dense)            (None, 304)               46512
#
#  dropout_46 (Dropout)        (None, 304)               0
#
#  dense_57 (Dense)            (None, 1)                 305
#
# =================================================================
# Total params: 209,229
# Trainable params: 209,229
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 2488/2488 [==============================] - 32s 12ms/step - loss: 0.0128 - recall: 0.0000e+00 - auc: 0.5120
# Epoch 2/20
# 2488/2488 [==============================] - 28s 11ms/step - loss: 0.0099 - recall: 0.0000e+00 - auc: 0.5331
# Epoch 3/20
# 2488/2488 [==============================] - 29s 12ms/step - loss: 0.0089 - recall: 0.0000e+00 - auc: 0.5199
# Epoch 4/20
# 2488/2488 [==============================] - 30s 12ms/step - loss: 0.0071 - recall: 0.0000e+00 - auc: 0.4978
# Epoch 5/20
# 2488/2488 [==============================] - 28s 11ms/step - loss: 0.0079 - recall: 0.0000e+00 - auc: 0.5041
# Epoch 6/20
# 2488/2488 [==============================] - 28s 11ms/step - loss: 0.0078 - recall: 0.0000e+00 - auc: 0.5018
# Epoch 7/20
# 2488/2488 [==============================] - 29s 12ms/step - loss: 0.0077 - recall: 0.0000e+00 - auc: 0.5009
# Epoch 8/20
# 2488/2488 [==============================] - 27s 11ms/step - loss: 0.0085 - recall: 0.0000e+00 - auc: 0.4974
# Epoch 9/20
# 2488/2488 [==============================] - 28s 11ms/step - loss: 0.0111 - recall: 0.0000e+00 - auc: 0.5023
# Epoch 10/20
# 2488/2488 [==============================] - 28s 11ms/step - loss: 0.0096 - recall: 0.0000e+00 - auc: 0.4952
# Epoch 11/20
# 2488/2488 [==============================] - 29s 11ms/step - loss: 0.0084 - recall: 0.0000e+00 - auc: 0.4971
# Epoch 12/20
# 2488/2488 [==============================] - 30s 12ms/step - loss: 0.0079 - recall: 0.0000e+00 - auc: 0.5057
# Epoch 13/20
# 2488/2488 [==============================] - 30s 12ms/step - loss: 0.0098 - recall: 0.0000e+00 - auc: 0.5046
# Epoch 14/20
# 2488/2488 [==============================] - 30s 12ms/step - loss: 0.0108 - recall: 0.0000e+00 - auc: 0.4972
# Epoch 15/20
# 2488/2488 [==============================] - 30s 12ms/step - loss: 0.0093 - recall: 0.0000e+00 - auc: 0.5009
# Epoch 16/20
# 2488/2488 [==============================] - 29s 12ms/step - loss: 0.0083 - recall: 0.0000e+00 - auc: 0.5042
# Epoch 17/20
# 2488/2488 [==============================] - 28s 11ms/step - loss: 0.0103 - recall: 0.0000e+00 - auc: 0.4995
# Epoch 18/20
# 2488/2488 [==============================] - 27s 11ms/step - loss: 0.0178 - recall: 0.0000e+00 - auc: 0.5008
# Epoch 19/20
# 2488/2488 [==============================] - 28s 11ms/step - loss: 0.0111 - recall: 0.0000e+00 - auc: 0.4993
# Epoch 20/20
# 2488/2488 [==============================] - 28s 11ms/step - loss: 0.0091 - recall: 0.0000e+00 - auc: 0.4997
# 2488/2488 [==============================] - 6s 2ms/step - loss: 0.0055 - recall: 0.0000e+00 - auc: 0.5000
# Loss Function: 0.0055459109134972095
# Test recall: 0.0
# Test auc: 0.5
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_58 (Dense)            (None, 304)               92720
#
#  dropout_47 (Dropout)        (None, 304)               0
#
#  dense_59 (Dense)            (None, 152)               46360
#
#  dropout_48 (Dropout)        (None, 152)               0
#
#  dense_60 (Dense)            (None, 76)                11628
#
#  dropout_49 (Dropout)        (None, 76)                0
#
#  dense_61 (Dense)            (None, 38)                2926
#
#  dropout_50 (Dropout)        (None, 38)                0
#
#  dense_62 (Dense)            (None, 76)                2964
#
#  dropout_51 (Dropout)        (None, 76)                0
#
#  dense_63 (Dense)            (None, 152)               11704
#
#  dropout_52 (Dropout)        (None, 152)               0
#
#  dense_64 (Dense)            (None, 304)               46512
#
#  dropout_53 (Dropout)        (None, 304)               0
#
#  dense_65 (Dense)            (None, 1)                 305
#
# =================================================================
# Total params: 215,119
# Trainable params: 215,119
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
display(Results)
# Out:
#            Modelo       AUC  Recall
# 0  model_number_1  0.500000     0.0
# 1  model_number_2  0.499227     0.0
# 2  model_number_3  0.500000     0.0
# 3  model_number_4  0.500000     0.0

# %% [markdown]
# ## 3.2 Results with imbalance class transformations

# %% [markdown]
# Training model 1

# %%
X = X_resampled
y = y_resampled

# %%
Results = pd.DataFrame()
recall = []
auc = []
name= []
i = 1
for model in models:
  model.fit(X, y, batch_size = 128, epochs = 20, verbose = 1)
  pred = model.predict(X_test_dense)
  score = model.evaluate(X_test_dense, y_test_dense, verbose=1)
  print('Loss Function:', score[0])
  print('Test recall:', score[1])
  print('Test auc:', score[2])
  print(model.summary())
  auc.append(score[2])
  recall.append(score[1])
  name.append('model_number_{}'.format(i))
  i = i+1

Results['Modelo'] = name
Results['AUC'] = auc 
Results['Recall'] = recall
# Out:
# Epoch 1/20
# 746/746 [==============================] - 18s 24ms/step - loss: 0.4912 - recall: 0.6096 - auc: 0.8728
# Epoch 2/20
# 746/746 [==============================] - 18s 24ms/step - loss: 0.1634 - recall: 0.9017 - auc: 0.9820
# Epoch 3/20
# 746/746 [==============================] - 18s 24ms/step - loss: 0.1039 - recall: 0.9530 - auc: 0.9921
# Epoch 4/20
# 746/746 [==============================] - 18s 24ms/step - loss: 0.0724 - recall: 0.9731 - auc: 0.9954
# Epoch 5/20
# 746/746 [==============================] - 18s 24ms/step - loss: 0.0585 - recall: 0.9802 - auc: 0.9967
# Epoch 6/20
# 746/746 [==============================] - 18s 24ms/step - loss: 0.0506 - recall: 0.9828 - auc: 0.9973
# Epoch 7/20
# 746/746 [==============================] - 18s 24ms/step - loss: 0.0417 - recall: 0.9874 - auc: 0.9980
# Epoch 8/20
# 746/746 [==============================] - 18s 24ms/step - loss: 0.0409 - recall: 0.9880 - auc: 0.9981
# Epoch 9/20
# 746/746 [==============================] - 18s 24ms/step - loss: 0.0327 - recall: 0.9907 - auc: 0.9985
# Epoch 10/20
# 746/746 [==============================] - 18s 24ms/step - loss: 0.0302 - recall: 0.9919 - auc: 0.9986
# Epoch 11/20
# 746/746 [==============================] - 18s 24ms/step - loss: 0.0291 - recall: 0.9928 - auc: 0.9987
# Epoch 12/20
# 746/746 [==============================] - 18s 25ms/step - loss: 0.0257 - recall: 0.9928 - auc: 0.9990
# Epoch 13/20
# 746/746 [==============================] - 18s 24ms/step - loss: 0.0228 - recall: 0.9948 - auc: 0.9990
# Epoch 14/20
# 746/746 [==============================] - 18s 24ms/step - loss: 0.0214 - recall: 0.9944 - auc: 0.9991
# Epoch 15/20
# 746/746 [==============================] - 18s 24ms/step - loss: 0.0207 - recall: 0.9951 - auc: 0.9992
# Epoch 16/20
# 746/746 [==============================] - 18s 24ms/step - loss: 0.0224 - recall: 0.9955 - auc: 0.9991
# Epoch 17/20
# 746/746 [==============================] - 18s 24ms/step - loss: 0.0195 - recall: 0.9959 - auc: 0.9992
# Epoch 18/20
# 746/746 [==============================] - 18s 24ms/step - loss: 0.0175 - recall: 0.9965 - auc: 0.9993
# Epoch 19/20
# 746/746 [==============================] - 18s 25ms/step - loss: 0.0183 - recall: 0.9964 - auc: 0.9993
# Epoch 20/20
# 746/746 [==============================] - 19s 25ms/step - loss: 0.0154 - recall: 0.9972 - auc: 0.9993
# 2488/2488 [==============================] - 10s 4ms/step - loss: 0.3131 - recall: 0.0000e+00 - auc: 0.5079
# Loss Function: 0.31309032440185547
# Test recall: 0.0
# Test auc: 0.507856011390686
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_44 (Dense)            (None, 304)               92720
#
#  dropout_36 (Dropout)        (None, 304)               0
#
#  dense_45 (Dense)            (None, 608)               185440
#
#  dropout_37 (Dropout)        (None, 608)               0
#
#  dense_46 (Dense)            (None, 608)               370272
#
#  dropout_38 (Dropout)        (None, 608)               0
#
#  dense_47 (Dense)            (None, 304)               185136
#
#  dropout_39 (Dropout)        (None, 304)               0
#
#  dense_48 (Dense)            (None, 1)                 305
#
# =================================================================
# Total params: 833,873
# Trainable params: 833,873
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.1984 - recall: 0.8711 - auc: 0.9736
# Epoch 2/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0848 - recall: 0.9726 - auc: 0.9943
# Epoch 3/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0570 - recall: 0.9854 - auc: 0.9970
# Epoch 4/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0439 - recall: 0.9899 - auc: 0.9981
# Epoch 5/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0365 - recall: 0.9929 - auc: 0.9984
# Epoch 6/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0319 - recall: 0.9930 - auc: 0.9988
# Epoch 7/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0271 - recall: 0.9953 - auc: 0.9989
# Epoch 8/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0244 - recall: 0.9959 - auc: 0.9991
# Epoch 9/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0208 - recall: 0.9959 - auc: 0.9993
# Epoch 10/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0189 - recall: 0.9971 - auc: 0.9993
# Epoch 11/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0171 - recall: 0.9970 - auc: 0.9994
# Epoch 12/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0159 - recall: 0.9971 - auc: 0.9995
# Epoch 13/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0149 - recall: 0.9970 - auc: 0.9996
# Epoch 14/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0135 - recall: 0.9975 - auc: 0.9996
# Epoch 15/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0138 - recall: 0.9981 - auc: 0.9995
# Epoch 16/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0115 - recall: 0.9979 - auc: 0.9997
# Epoch 17/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0109 - recall: 0.9981 - auc: 0.9996
# Epoch 18/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0111 - recall: 0.9983 - auc: 0.9996
# Epoch 19/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0105 - recall: 0.9985 - auc: 0.9996
# Epoch 20/20
# 746/746 [==============================] - 6s 8ms/step - loss: 0.0105 - recall: 0.9977 - auc: 0.9996
# 2488/2488 [==============================] - 5s 2ms/step - loss: 0.0455 - recall: 0.0189 - auc: 0.5074
# Loss Function: 0.04554291442036629
# Test recall: 0.01886792480945587
# Test auc: 0.5073797702789307
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_49 (Dense)            (None, 304)               92720
#
#  dropout_40 (Dropout)        (None, 304)               0
#
#  dense_50 (Dense)            (None, 304)               92720
#
#  dropout_41 (Dropout)        (None, 304)               0
#
#  dense_51 (Dense)            (None, 1)                 305
#
# =================================================================
# Total params: 185,745
# Trainable params: 185,745
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.6740 - recall: 0.0238 - auc: 0.5007
# Epoch 2/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.6444 - recall: 0.0080 - auc: 0.5085
# Epoch 3/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.4328 - recall: 0.5759 - auc: 0.8492
# Epoch 4/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.1355 - recall: 0.9708 - auc: 0.9810
# Epoch 5/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.0678 - recall: 0.9847 - auc: 0.9932
# Epoch 6/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.0474 - recall: 0.9910 - auc: 0.9957
# Epoch 7/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.0365 - recall: 0.9925 - auc: 0.9972
# Epoch 8/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.0264 - recall: 0.9946 - auc: 0.9980
# Epoch 9/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.0252 - recall: 0.9947 - auc: 0.9981
# Epoch 10/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.0209 - recall: 0.9956 - auc: 0.9986
# Epoch 11/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.0199 - recall: 0.9956 - auc: 0.9986
# Epoch 12/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.0182 - recall: 0.9957 - auc: 0.9988
# Epoch 13/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.0162 - recall: 0.9967 - auc: 0.9990
# Epoch 14/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.0135 - recall: 0.9973 - auc: 0.9991
# Epoch 15/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.0152 - recall: 0.9964 - auc: 0.9991
# Epoch 16/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.0140 - recall: 0.9975 - auc: 0.9992
# Epoch 17/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.0138 - recall: 0.9972 - auc: 0.9992
# Epoch 18/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.0104 - recall: 0.9977 - auc: 0.9994
# Epoch 19/20
# 746/746 [==============================] - 9s 12ms/step - loss: 0.0089 - recall: 0.9983 - auc: 0.9995
# Epoch 20/20
# 746/746 [==============================] - 8s 10ms/step - loss: 0.0123 - recall: 0.9981 - auc: 0.9993
# 2488/2488 [==============================] - 5s 2ms/step - loss: 0.1077 - recall: 0.0566 - auc: 0.5339
# Loss Function: 0.10766660422086716
# Test recall: 0.056603774428367615
# Test auc: 0.5338565707206726
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_52 (Dense)            (None, 304)               92720
#
#  dropout_42 (Dropout)        (None, 304)               0
#
#  dense_53 (Dense)            (None, 152)               46360
#
#  dropout_43 (Dropout)        (None, 152)               0
#
#  dense_54 (Dense)            (None, 76)                11628
#
#  dropout_44 (Dropout)        (None, 76)                0
#
#  dense_55 (Dense)            (None, 152)               11704
#
#  dropout_45 (Dropout)        (None, 152)               0
#
#  dense_56 (Dense)            (None, 304)               46512
#
#  dropout_46 (Dropout)        (None, 304)               0
#
#  dense_57 (Dense)            (None, 1)                 305
#
# =================================================================
# Total params: 209,229
# Trainable params: 209,229
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.6696 - recall: 0.0195 - auc: 0.4978
# Epoch 2/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.6199 - recall: 0.0333 - auc: 0.5734
# Epoch 3/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.3238 - recall: 0.8062 - auc: 0.9189
# Epoch 4/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.1091 - recall: 0.9797 - auc: 0.9857
# Epoch 5/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.0622 - recall: 0.9881 - auc: 0.9937
# Epoch 6/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.0406 - recall: 0.9920 - auc: 0.9964
# Epoch 7/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.0294 - recall: 0.9938 - auc: 0.9976
# Epoch 8/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.0241 - recall: 0.9942 - auc: 0.9983
# Epoch 9/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.0204 - recall: 0.9952 - auc: 0.9986
# Epoch 10/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.0181 - recall: 0.9958 - auc: 0.9988
# Epoch 11/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.0142 - recall: 0.9961 - auc: 0.9992
# Epoch 12/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.0136 - recall: 0.9969 - auc: 0.9992
# Epoch 13/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.0129 - recall: 0.9977 - auc: 0.9991
# Epoch 14/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.0137 - recall: 0.9975 - auc: 0.9992
# Epoch 15/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.0129 - recall: 0.9976 - auc: 0.9992
# Epoch 16/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.0105 - recall: 0.9981 - auc: 0.9994
# Epoch 17/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.0104 - recall: 0.9983 - auc: 0.9993
# Epoch 18/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.0112 - recall: 0.9980 - auc: 0.9994
# Epoch 19/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.0077 - recall: 0.9984 - auc: 0.9996
# Epoch 20/20
# 746/746 [==============================] - 8s 11ms/step - loss: 0.0110 - recall: 0.9977 - auc: 0.9993
# 2488/2488 [==============================] - 5s 2ms/step - loss: 0.0628 - recall: 0.0000e+00 - auc: 0.5161
# Loss Function: 0.06284987181425095
# Test recall: 0.0
# Test auc: 0.5160624980926514
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_58 (Dense)            (None, 304)               92720
#
#  dropout_47 (Dropout)        (None, 304)               0
#
#  dense_59 (Dense)            (None, 152)               46360
#
#  dropout_48 (Dropout)        (None, 152)               0
#
#  dense_60 (Dense)            (None, 76)                11628
#
#  dropout_49 (Dropout)        (None, 76)                0
#
#  dense_61 (Dense)            (None, 38)                2926
#
#  dropout_50 (Dropout)        (None, 38)                0
#
#  dense_62 (Dense)            (None, 76)                2964
#
#  dropout_51 (Dropout)        (None, 76)                0
#
#  dense_63 (Dense)            (None, 152)               11704
#
#  dropout_52 (Dropout)        (None, 152)               0
#
#  dense_64 (Dense)            (None, 304)               46512
#
#  dropout_53 (Dropout)        (None, 304)               0
#
#  dense_65 (Dense)            (None, 1)                 305
#
# =================================================================
# Total params: 215,119
# Trainable params: 215,119
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
display(Results)
# Out:
#            Modelo       AUC    Recall
# 0  model_number_1  0.507856  0.000000
# 1  model_number_2  0.507380  0.018868
# 2  model_number_3  0.533857  0.056604
# 3  model_number_4  0.516062  0.000000

# %% [markdown]
# ## 3.3 Results Genetic Algorithm regularization

# %%
variables = ['total_conversions', 'device_make', 'inventory_source', 'tod', 'ad_type',
 'browser', 'os', 'insertion_order', 'creative_name', 'device_type',
 'device_make', 'inventory_source', 'post_click_conversions',
 'post_view_conversions', 'total_conversions', 'viewable_impressions',
 'creative_size', 'billable_impressions', 'tod', 'device_type',
 'media_cost_log', 'impressions', 'viewable_impressions', 'creative_size',
 'post_view_conversions', 'day_of_week']

# %%
X_data.columns.tolist()
# Out:
# ['impressions',
#  'billable_impressions',
#  'viewable_impressions',
#  'total_conversions',
#  'post_view_conversions',
#  'media_cost_log',
#  'total_media_cost_log',
#  'device_model',
#  'app_url',
#  'city',
#  'date_03/04/2022',
#  'date_06/04/2022',
#  'date_08/04/2022',
#  'date_11/04/2022',
#  'date_16/04/2022',
#  'date_17/04/2022',
#  'tod_tod_10',
#  'tod_tod_11',
#  'tod_tod_12',
#  'tod_tod_13',
#  'tod_tod_14',
#  'tod_tod_15',
#  'tod_tod_16',
#  'tod_tod_17',
#  'tod_tod_18',
#  'tod_tod_19',
#  'tod_tod_2',
#  'tod_tod_20',
#  'tod_tod_21',
#  'tod_tod_22',
#  'tod_tod_23',
#  'tod_tod_24',
#  'tod_tod_3',
#  'tod_tod_4',
#  'tod_tod_5',
#  'tod_tod_6',
#  'tod_tod_7',
#  'tod_tod_8',
#  'tod_tod_9',
#  'insertion_order_insertion_order2',
#  'insertion_order_insertion_order3',
#  'line_item_line_item10',
#  'line_item_line_item11',
#  'line_item_line_item12',
#  'line_item_line_item13',
#  'line_item_line_item14',
#  'line_item_line_item15',
#  'line_item_line_item16',
#  'line_item_line_item17',
#  'line_item_line_item18',
#  'line_item_line_item19',
#  'line_item_line_item2',
#  'line_item_line_item20',
#  'line_item_line_item21',
#  'line_item_line_item22',
#  'line_item_line_item23',
#  'line_item_line_item24',
#  'line_item_line_item25',
#  'line_item_line_item26',
#  'line_item_line_item27',
#  'line_item_line_item28',
#  'line_item_line_item29',
#  'line_item_line_item3',
#  'line_item_line_item30',
#  'line_item_line_item31',
#  'line_item_line_item32',
#  'line_item_line_item33',
#  'line_item_line_item34',
#  'line_item_line_item4',
#  'line_item_line_item5',
#  'line_item_line_item6',
#  'line_item_line_item7',
#  'line_item_line_item8',
#  'line_item_line_item9',
#  'device_type_Desktop',
#  'device_type_Smart Phone',
#  'device_type_Tablet',
#  'device_make_Alcatel (All Models)',
#  'device_make_Amazon (All Models)',
#  'device_make_Amlogic (All Models)',
#  'device_make_Apple (All Models)',
#  'device_make_Archos (All Models)',
#  'device_make_Asus (All Models)',
#  'device_make_BlackBerry (All Models)',
#  'device_make_Chuwi (All Models)',
#  'device_make_Cube (All Models)',
#  'device_make_Cubot (All Models)',
#  'device_make_DOOGEE (All Models)',
#  'device_make_Eken (All Models)',
#  'device_make_Evertek (All Models)',
#  'device_make_General Mobile (All Models)',
#  'device_make_Generic (All Models)',
#  'device_make_Gionee (All Models)',
#  'device_make_Google (All Models)',
#  'device_make_HTC (All Models)',
#  'device_make_HUAWEI (All Models)',
#  'device_make_IMO (All Models)',
#  'device_make_Karbonn (All Models)',
#  'device_make_Kyocera (All Models)',
#  'device_make_LG (All Models)',
#  'device_make_Lava (All Models)',
#  'device_make_Lenovo (All Models)',
#  'device_make_Medion (All Models)',
#  'device_make_Meizu (All Models)',
#  'device_make_Micromax (All Models)',
#  'device_make_Microsoft (All Models)',
#  'device_make_Motorola (All Models)',
#  'device_make_Mozilla (All Models)',
#  'device_make_Nokia (All Models)',
#  'device_make_OPPO (All Models)',
#  'device_make_Prestigio (All Models)',
#  'device_make_RCA (All Models)',
#  'device_make_Samsung (All Models)',
#  'device_make_Sharp (All Models)',
#  'device_make_Sony (All Models)',
#  'device_make_T-Mobile (All Models)',
#  'device_make_TCL (All Models)',
#  'device_make_Teclast (All Models)',
#  'device_make_Tecno (All Models)',
#  'device_make_Tesco (All Models)',
#  'device_make_ThL (All Models)',
#  'device_make_Unknown',
#  'device_make_Vivo (All Models)',
#  'device_make_Vodafone (All Models)',
#  'device_make_Wiko (All Models)',
#  'device_make_Xiaomi (All Models)',
#  'device_make_ZTE (All Models)',
#  'os_Android 10.0',
#  'os_Android 11.0',
#  'os_Android 12.0',
#  'os_Android 4.0',
#  'os_Android 4.1',
#  'os_Android 4.2',
#  'os_Android 4.3',
#  'os_Android 4.4',
#  'os_Android 5.0',
#  'os_Android 5.1',
#  'os_Android 6.0',
#  'os_Android 7.0',
#  'os_Android 7.1',
#  'os_Android 8.0',
#  'os_Android 8.1',
#  'os_Android 9.0',
#  'os_Android 9.1',
#  'os_MacOS',
#  'os_Other',
#  'os_Windows Other',
#  'os_Windows10',
#  'os_Windows7',
#  'os_Windows8',
#  'os_WindowsVista',
#  'os_iOS',
#  'os_iOS 10.3',
#  'os_iOS 11.1',
#  'os_iOS 11.3',
#  'os_iOS 11.4',
#  'os_iOS 12.0',
#  'os_iOS 12.1',
#  'os_iOS 12.2',
#  'os_iOS 12.3',
#  'os_iOS 12.4',
#  'os_iOS 12.5',
#  'os_iOS 13.0',
#  'os_iOS 13.1',
#  'os_iOS 13.2',
#  'os_iOS 13.3',
#  'os_iOS 13.4',
#  'os_iOS 13.5',
#  'os_iOS 13.6',
#  'os_iOS 13.7',
#  'os_iOS 14.0',
#  'os_iOS 14.1',
#  'os_iOS 14.2',
#  'os_iOS 14.3',
#  'os_iOS 14.4',
#  'os_iOS 14.5',
#  'os_iOS 14.6',
#  'os_iOS 14.7',
#  'os_iOS 14.8',
#  'os_iOS 15.0',
#  'os_iOS 15.1',
#  'os_iOS 15.2',
#  'os_iOS 15.3',
#  'os_iOS 15.4',
#  'os_iOS 6.0',
#  'os_iOS 7.0',
#  'os_iOS 8.0',
#  'os_iOS 9.3',
#  'browser_Firefox',
#  'browser_Google Chrome',
#  'browser_Microsoft Edge',
#  'browser_Microsoft Internet Explorer 11',
#  'browser_Microsoft Internet Explorer 7',
#  'browser_Opera',
#  'browser_Other',
#  'browser_Safari (iPad)',
#  'browser_Safari (iPhone/iPod)',
#  'browser_Safari 12',
#  'browser_Safari 13',
#  'browser_Safari 14',
#  'browser_Safari Other',
#  'browser_Yandex',
#  'isp_carrier_BT',
#  'isp_carrier_Bredband2',
#  'isp_carrier_Century Link',
#  'isp_carrier_China Mobile',
#  'isp_carrier_China Telecom',
#  'isp_carrier_Cyta',
#  'isp_carrier_DSL Extreme',
#  'isp_carrier_Daisy',
#  'isp_carrier_Digital Ocean',
#  'isp_carrier_EE',
#  'isp_carrier_Eircom',
#  'isp_carrier_Forthnet',
#  'isp_carrier_HKBN',
#  'isp_carrier_Intertelecom',
#  'isp_carrier_KPN',
#  'isp_carrier_Mobile Other',
#  'isp_carrier_Neotel',
#  'isp_carrier_O2 in GB',
#  'isp_carrier_Online Breedband',
#  'isp_carrier_Orange',
#  'isp_carrier_Orange in GB',
#  'isp_carrier_Orange in IL',
#  'isp_carrier_Plusnet',
#  'isp_carrier_RCS & RDS',
#  'isp_carrier_SKY Broadband',
#  'isp_carrier_SatNet',
#  'isp_carrier_SuperCarrier in DE',
#  'isp_carrier_SuperCarrier in FR',
#  'isp_carrier_SuperCarrier in GB',
#  'isp_carrier_SuperCarrier in SE',
#  'isp_carrier_SuperCarrier in US',
#  'isp_carrier_T-Mobile in HU',
#  'isp_carrier_TalkTalk',
#  'isp_carrier_Telecom Italia in IT',
#  'isp_carrier_Telekom Romania',
#  'isp_carrier_TeliaSonera',
#  'isp_carrier_Three',
#  'isp_carrier_Versatel',
#  'isp_carrier_Virgin Media',
#  'isp_carrier_Vodafone',
#  'isp_carrier_Vodafone in GB',
#  'isp_carrier_Zen Internet',
#  'creative_name_creative_name10',
#  'creative_name_creative_name2',
#  'creative_name_creative_name3',
#  'creative_name_creative_name4',
#  'creative_name_creative_name5',
#  'creative_name_creative_name6',
#  'creative_name_creative_name7',
#  'creative_name_creative_name8',
#  'creative_name_creative_name9',
#  'creative_size_300x600',
#  'creative_size_320x100',
#  'creative_size_320x50',
#  'channel_name_GroupM_Inclusion List',
#  'channel_name_Over-the-Top Publishers',
#  'channel_name_Top 2000 Global Sites for Nielsen Display Ads',
#  'channel_name_Top 2000 Global Sites for Nielsen Video Ads',
#  'channel_name_Top 2000 US Sites for Nielsen Display Ads',
#  'channel_name_Top 2000 US Sites for Nielsen Video Ads',
#  'channel_name_Top 2000 non-US Sites for Nielsen Display Ads',
#  'channel_name_Top 2000 non-US Sites for Nielsen Video Ads',
#  'exchange_AppNexus (Xandr)',
#  'exchange_BidSwitch',
#  'exchange_Google Ad Manager',
#  'exchange_GumGum',
#  'exchange_Improve Digital',
#  'exchange_Index Exchange',
#  'exchange_Magnite DV+',
#  'exchange_OpenX',
#  'exchange_PubMatic',
#  'exchange_PulsePoint',
#  'exchange_Smart RTB+ (Smartadserver)',
#  'exchange_Sovrn',
#  'exchange_TeadsTv',
#  'exchange_TripleLift',
#  'exchange_Verizon Media Exchange',
#  'inventory_source_Adyoulike',
#  'inventory_source_AerServ',
#  'inventory_source_Beachfront',
#  'inventory_source_Colossus',
#  'inventory_source_EMX Digital',
#  'inventory_source_Media.net',
#  'inventory_source_OneTag',
#  'inventory_source_Outbrain',
#  'inventory_source_RhythmOne (AdConductor)',
#  'inventory_source_Seedtag',
#  'inventory_source_Sonobi',
#  'inventory_source_The MediaGrid',
#  'inventory_source_Unknown or Unpermissioned Inventory Source',
#  'inventory_source_UnrulyX',
#  'inventory_source_Yieldmo',
#  'ad_position_BELOW_THE_FOLD',
#  'ad_position_Unknown',
#  'ad_type_Unknown',
#  'position_in_content_Interstitial',
#  'position_in_content_Pre-roll',
#  'position_in_content_Unknown - Out-stream',
#  'day_of_week_Monday',
#  'day_of_week_Saturday',
#  'day_of_week_Sunday',
#  'day_of_week_Wednesday']
